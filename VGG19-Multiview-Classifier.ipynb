# %% [markdown]
# **Dataset folder structure:**
#
# The root folder '/content/drive/MyDrive/FARIL-SORG/cartilaginous-tumors-dataset' should contain two subfolders, "train" and "val", where the "train" folder contains two subfolders, "chondrosarcoma" and "enchondroma" and the "val" folder also contains two subfolders, "chondrosarcoma" and "enchondroma".
#
# Each patient has a folder corresponding to their ID that contains their two images, should be placed in the appropriate subfolder. It's good practice to randomly split the patient data so that 80% of the patients are in the "train" folder and the remaining 20% are in the "val" folder.
#
# With this folder structure, you can use the flow_from_directory method of the ImageDataGenerator class to automatically generate batches of images and labels for training and validation. This method will look into the subfolders and automatically label the images according to the folder they are in.
#
# This lets you load the data by passing the path of the train and val folders to the flow_from_directory method.

# %% [markdown]
# ![Folders.jpg](data:image/jpeg;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras import models
from keras import optimizers
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, concatenate, Dropout
from keras.applications.vgg19 import VGG19
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
seed = 42
num_epochs = 50
batch_size = 16

# path to dataset on google drive
path_to_dataset = '/content/drive/MyDrive/FARIL-SORG/cartilaginous-tumors-dataset'

# %%
# create an ImageDataGenerator object
datagen = ImageDataGenerator(
    rescale=1./255,  # normalize pixel values
    rotation_range=40,  # randomly rotate images by up to 40 degrees
    #rotation_range=10,  # randomly rotate images by up to 10 degrees
    width_shift_range=0.2,  # randomly shift images horizontally
    height_shift_range=0.2,  # randomly shift images vertically
    #width_shift_range=0.1,  # randomly shift images horizontally
    #height_shift_range=0.1,  # randomly shift images vertically
    shear_range=0.2,  # randomly apply shearing transformations
    zoom_range=0.2,  # randomly zoom in and out
    #shear_range=0.1,  # randomly apply shearing transformations
    #zoom_range=0.1,  # randomly zoom in and out
    horizontal_flip=True,  # randomly flip images horizontally
    fill_mode='nearest')  # fill in newly created pixels

# create a generator for training data
train_generator = datagen.flow_from_directory(
    os.path.join(path_to_dataset, 'train'),  # directory containing training data
    target_size=(224, 224),  # resize images to 224x224 pixels
    batch_size=16, # modify the batch size
    shuffle=True,
    class_mode='categorical',
    seed=seed
)

# create a generator for validation data
val_generator = datagen.flow_from_directory(
    os.path.join(path_to_dataset, 'val'),  # directory containing validation data
    target_size=(224, 224),  # resize images to 224x224 pixels
    batch_size=16, # modify the batch size
    shuffle=True,
    class_mode='categorical',
    seed=seed
)

# specify the number of steps to take from the generator before moving to the next epoch
steps_per_epoch = train_generator.n // train_generator.batch_size
validation_steps = val_generator.n // val_generator.batch_size

# Load VGG16 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers
for layer in base_model.layers:
    layer.trainable = False

# define two input layers for the two images
input_img1 = Input(shape=(224, 224, 3))
input_img2 = Input(shape=(224, 224, 3))

# Load VGG16 model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Get output of VGG16 model for image 1
x1 = base_model(input_img1)

# Get output of VGG16 model for image 2
x2 = base_model(input_img2)

# Concatenate the output
concatenated_output = concatenate([x1, x2])

# specify the weight decay rate
weight_decay = 1e-3

# add additional layers, and EXPERIMENT WITH DIFFERENT HYPERPARAMETERS
# Units: 128, 256, 512, 1024
# Dropout: min_value=0.0, max_value=0.5, step=0.1
# Learning rate: min_value=1e-4, max_value=1e-2, step=1e-4
# Weight decay: 0.001, 0.0001, 0.00001, 0.000001 (1e-3 to 1e-6)

# add additional layers
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay))(x)
x = Dropout(0.5)(x)
predictions = Dense(2, activation='softmax')(x)

# create the final model
model = Model(inputs=base_model.input, outputs=predictions)

# freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=weight_decay)

# compile the model
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['acc'])

# early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)

# save the best model
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
# Out:
# Found 980 images belonging to 2 classes.
# Found 236 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
history = model.fit_generator(train_generator,
                              steps_per_epoch=int(980/batch_size),
                              epochs=50,
                              validation_data=val_generator,
                              validation_steps=int(244/batch_size),
                              callbacks=[early_stop, model_checkpoint])
# Out:
# <ipython-input-5-34d441bc7861>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/50
# 61/61 [==============================] - ETA: 0s - loss: 1.2589 - acc: 0.5373
# Epoch 1: val_loss improved from inf to 1.01525, saving model to best_model.h5
# 61/61 [==============================] - 209s 3s/step - loss: 1.2589 - acc: 0.5373 - val_loss: 1.0153 - val_acc: 0.5678
# Epoch 2/50
# 61/61 [==============================] - ETA: 0s - loss: 0.9479 - acc: 0.6286
# Epoch 2: val_loss improved from 1.01525 to 0.91334, saving model to best_model.h5
# 61/61 [==============================] - 43s 702ms/step - loss: 0.9479 - acc: 0.6286 - val_loss: 0.9133 - val_acc: 0.5932
# Epoch 3/50
# 61/61 [==============================] - ETA: 0s - loss: 0.8993 - acc: 0.6286
# Epoch 3: val_loss improved from 0.91334 to 0.86272, saving model to best_model.h5
# 61/61 [==============================] - 43s 702ms/step - loss: 0.8993 - acc: 0.6286 - val_loss: 0.8627 - val_acc: 0.6525
# Epoch 4/50
# 61/61 [==============================] - ETA: 0s - loss: 0.8499 - acc: 0.6618
# Epoch 4: val_loss did not improve from 0.86272
# 61/61 [==============================] - 42s 697ms/step - loss: 0.8499 - acc: 0.6618 - val_loss: 0.8700 - val_acc: 0.5932
# Epoch 5/50
# 61/61 [==============================] - ETA: 0s - loss: 0.8311 - acc: 0.6546
# Epoch 5: val_loss did not improve from 0.86272
# 61/61 [==============================] - 42s 697ms/step - loss: 0.8311 - acc: 0.6546 - val_loss: 0.8686 - val_acc: 0.6186
# Epoch 6/50
# 61/61 [==============================] - ETA: 0s - loss: 0.8127 - acc: 0.6753
# Epoch 6: val_loss improved from 0.86272 to 0.82047, saving model to best_model.h5
# 61/61 [==============================] - 43s 704ms/step - loss: 0.8127 - acc: 0.6753 - val_loss: 0.8205 - val_acc: 0.6610
# Epoch 7/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7962 - acc: 0.6784
# Epoch 7: val_loss did not improve from 0.82047
# 61/61 [==============================] - 42s 694ms/step - loss: 0.7962 - acc: 0.6784 - val_loss: 0.8309 - val_acc: 0.6314
# Epoch 8/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7867 - acc: 0.6919
# Epoch 8: val_loss did not improve from 0.82047
# 61/61 [==============================] - 42s 692ms/step - loss: 0.7867 - acc: 0.6919 - val_loss: 0.8492 - val_acc: 0.6398
# Epoch 9/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7827 - acc: 0.6878
# Epoch 9: val_loss improved from 0.82047 to 0.80272, saving model to best_model.h5
# 61/61 [==============================] - 43s 705ms/step - loss: 0.7827 - acc: 0.6878 - val_loss: 0.8027 - val_acc: 0.6314
# Epoch 10/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7615 - acc: 0.6898
# Epoch 10: val_loss did not improve from 0.80272
# 61/61 [==============================] - 42s 689ms/step - loss: 0.7615 - acc: 0.6898 - val_loss: 0.8062 - val_acc: 0.6356
# Epoch 11/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7507 - acc: 0.6929
# Epoch 11: val_loss improved from 0.80272 to 0.76649, saving model to best_model.h5
# 61/61 [==============================] - 43s 699ms/step - loss: 0.7507 - acc: 0.6929 - val_loss: 0.7665 - val_acc: 0.6864
# Epoch 12/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7507 - acc: 0.6888
# Epoch 12: val_loss did not improve from 0.76649
# 61/61 [==============================] - 42s 695ms/step - loss: 0.7507 - acc: 0.6888 - val_loss: 0.7810 - val_acc: 0.6610
# Epoch 13/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7246 - acc: 0.7261
# Epoch 13: val_loss did not improve from 0.76649
# 61/61 [==============================] - 42s 693ms/step - loss: 0.7246 - acc: 0.7261 - val_loss: 0.7750 - val_acc: 0.6822
# Epoch 14/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7234 - acc: 0.7095
# Epoch 14: val_loss did not improve from 0.76649
# 61/61 [==============================] - 42s 694ms/step - loss: 0.7234 - acc: 0.7095 - val_loss: 0.8046 - val_acc: 0.6398
# Epoch 15/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7230 - acc: 0.7137
# Epoch 15: val_loss did not improve from 0.76649
# 61/61 [==============================] - 42s 696ms/step - loss: 0.7230 - acc: 0.7137 - val_loss: 0.7950 - val_acc: 0.6483
# Epoch 16/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7007 - acc: 0.7230
# Epoch 16: val_loss improved from 0.76649 to 0.76446, saving model to best_model.h5
# 61/61 [==============================] - 43s 703ms/step - loss: 0.7007 - acc: 0.7230 - val_loss: 0.7645 - val_acc: 0.6610
# Epoch 17/50
# 61/61 [==============================] - ETA: 0s - loss: 0.7007 - acc: 0.7095
# Epoch 17: val_loss did not improve from 0.76446
# 61/61 [==============================] - 42s 693ms/step - loss: 0.7007 - acc: 0.7095 - val_loss: 0.7694 - val_acc: 0.6992
# Epoch 18/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6862 - acc: 0.7251
# Epoch 18: val_loss did not improve from 0.76446
# 61/61 [==============================] - 42s 697ms/step - loss: 0.6862 - acc: 0.7251 - val_loss: 0.7866 - val_acc: 0.6483
# Epoch 19/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6659 - acc: 0.7448
# Epoch 19: val_loss did not improve from 0.76446
# 61/61 [==============================] - 42s 695ms/step - loss: 0.6659 - acc: 0.7448 - val_loss: 0.8121 - val_acc: 0.6314
# Epoch 20/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6630 - acc: 0.7438
# Epoch 20: val_loss improved from 0.76446 to 0.72865, saving model to best_model.h5
# 61/61 [==============================] - 43s 700ms/step - loss: 0.6630 - acc: 0.7438 - val_loss: 0.7286 - val_acc: 0.7161
# Epoch 21/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6626 - acc: 0.7303
# Epoch 21: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 699ms/step - loss: 0.6626 - acc: 0.7303 - val_loss: 0.7650 - val_acc: 0.6610
# Epoch 22/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6417 - acc: 0.7624
# Epoch 22: val_loss did not improve from 0.72865
# 61/61 [==============================] - 42s 694ms/step - loss: 0.6417 - acc: 0.7624 - val_loss: 0.7629 - val_acc: 0.6483
# Epoch 23/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6607 - acc: 0.7459
# Epoch 23: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 700ms/step - loss: 0.6607 - acc: 0.7459 - val_loss: 0.7623 - val_acc: 0.6525
# Epoch 24/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6295 - acc: 0.7604
# Epoch 24: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 699ms/step - loss: 0.6295 - acc: 0.7604 - val_loss: 0.7346 - val_acc: 0.7076
# Epoch 25/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6326 - acc: 0.7676
# Epoch 25: val_loss did not improve from 0.72865
# 61/61 [==============================] - 42s 693ms/step - loss: 0.6326 - acc: 0.7676 - val_loss: 0.7436 - val_acc: 0.6695
# Epoch 26/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6291 - acc: 0.7510
# Epoch 26: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 700ms/step - loss: 0.6291 - acc: 0.7510 - val_loss: 0.7758 - val_acc: 0.6610
# Epoch 27/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6094 - acc: 0.7739
# Epoch 27: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 700ms/step - loss: 0.6094 - acc: 0.7739 - val_loss: 0.7546 - val_acc: 0.6864
# Epoch 28/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6146 - acc: 0.7656
# Epoch 28: val_loss did not improve from 0.72865
# 61/61 [==============================] - 43s 697ms/step - loss: 0.6146 - acc: 0.7656 - val_loss: 0.7414 - val_acc: 0.6568
# Epoch 29/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6149 - acc: 0.7645
# Epoch 29: val_loss improved from 0.72865 to 0.71393, saving model to best_model.h5
# 61/61 [==============================] - 43s 701ms/step - loss: 0.6149 - acc: 0.7645 - val_loss: 0.7139 - val_acc: 0.7373
# Epoch 30/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5945 - acc: 0.7770
# Epoch 30: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 699ms/step - loss: 0.5945 - acc: 0.7770 - val_loss: 0.7447 - val_acc: 0.6822
# Epoch 31/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6181 - acc: 0.7739
# Epoch 31: val_loss did not improve from 0.71393
# 61/61 [==============================] - 42s 694ms/step - loss: 0.6181 - acc: 0.7739 - val_loss: 0.7459 - val_acc: 0.6356
# Epoch 32/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5939 - acc: 0.7894
# Epoch 32: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 699ms/step - loss: 0.5939 - acc: 0.7894 - val_loss: 0.7645 - val_acc: 0.6356
# Epoch 33/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6034 - acc: 0.7604
# Epoch 33: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 703ms/step - loss: 0.6034 - acc: 0.7604 - val_loss: 0.7478 - val_acc: 0.6695
# Epoch 34/50
# 61/61 [==============================] - ETA: 0s - loss: 0.6058 - acc: 0.7562
# Epoch 34: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 699ms/step - loss: 0.6058 - acc: 0.7562 - val_loss: 0.7526 - val_acc: 0.6737
# Epoch 35/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5790 - acc: 0.7925
# Epoch 35: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 700ms/step - loss: 0.5790 - acc: 0.7925 - val_loss: 0.7322 - val_acc: 0.6780
# Epoch 36/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5616 - acc: 0.7941
# Epoch 36: val_loss did not improve from 0.71393
# 61/61 [==============================] - 43s 708ms/step - loss: 0.5616 - acc: 0.7941 - val_loss: 0.7386 - val_acc: 0.7034
# Epoch 37/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5699 - acc: 0.7770
# Epoch 37: val_loss did not improve from 0.71393
# 61/61 [==============================] - 42s 696ms/step - loss: 0.5699 - acc: 0.7770 - val_loss: 0.7527 - val_acc: 0.6568
# Epoch 38/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5621 - acc: 0.7936
# Epoch 38: val_loss improved from 0.71393 to 0.68580, saving model to best_model.h5
# 61/61 [==============================] - 42s 699ms/step - loss: 0.5621 - acc: 0.7936 - val_loss: 0.6858 - val_acc: 0.7458
# Epoch 39/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5624 - acc: 0.7956
# Epoch 39: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 693ms/step - loss: 0.5624 - acc: 0.7956 - val_loss: 0.7113 - val_acc: 0.6907
# Epoch 40/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5599 - acc: 0.7967
# Epoch 40: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 696ms/step - loss: 0.5599 - acc: 0.7967 - val_loss: 0.7738 - val_acc: 0.6441
# Epoch 41/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5657 - acc: 0.8029
# Epoch 41: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 696ms/step - loss: 0.5657 - acc: 0.8029 - val_loss: 0.7172 - val_acc: 0.6695
# Epoch 42/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5505 - acc: 0.7977
# Epoch 42: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 694ms/step - loss: 0.5505 - acc: 0.7977 - val_loss: 0.7282 - val_acc: 0.6780
# Epoch 43/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5370 - acc: 0.8174
# Epoch 43: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 696ms/step - loss: 0.5370 - acc: 0.8174 - val_loss: 0.7516 - val_acc: 0.6695
# Epoch 44/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5513 - acc: 0.7998
# Epoch 44: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 698ms/step - loss: 0.5513 - acc: 0.7998 - val_loss: 0.7317 - val_acc: 0.6992
# Epoch 45/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5563 - acc: 0.7925
# Epoch 45: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 696ms/step - loss: 0.5563 - acc: 0.7925 - val_loss: 0.7734 - val_acc: 0.6653
# Epoch 46/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5470 - acc: 0.7967
# Epoch 46: val_loss did not improve from 0.68580
# 61/61 [==============================] - 43s 700ms/step - loss: 0.5470 - acc: 0.7967 - val_loss: 0.7373 - val_acc: 0.6737
# Epoch 47/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5345 - acc: 0.7988
# Epoch 47: val_loss did not improve from 0.68580
# 61/61 [==============================] - 42s 699ms/step - loss: 0.5345 - acc: 0.7988 - val_loss: 0.7622 - val_acc: 0.6822
# Epoch 48/50
# 61/61 [==============================] - ETA: 0s - loss: 0.5338 - acc: 0.8039
# Epoch 48: val_loss did not improve from 0.68580
# 61/61 [==============================] - 43s 701ms/step - loss: 0.5338 - acc: 0.8039 - val_loss: 0.7366 - val_acc: 0.6864
# Epoch 48: early stopping

# %%
# import Matplotlib
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# ## Now let's apply Keras Tuner to optimize the hyperparameters automatically!

# %%
import kerastuner
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-f829eee6c585> in <module>
# ----> 1 import kerastuner
#
# ModuleNotFoundError: No module named 'kerastuner'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install keras-tuner

# %%
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

def build_model(hp):
    # define two input layers for the two images
    input_img1 = Input(shape=(224, 224, 3))
    input_img2 = Input(shape=(224, 224, 3))

    # Load VGG16 model
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Get output of VGG16 model for image 1
    x1 = base_model(input_img1)

    # Get output of VGG16 model for image 2
    x2 = base_model(input_img2)

    # Concatenate the output
    concatenated_output = concatenate([x1, x2])

    # add additional layers
    x = concatenated_output
    x = Flatten()(x)
    x = Dense(hp.Int('units', 64, 256, step=32), activation='relu')(x)
    x = Dropout(hp.Float('dropout', 0, 0.5))(x)
    predictions = Dense(2, activation='softmax')(x)

    model = Model(inputs=[input_img1, input_img2], outputs=predictions)
    model.compile(
        optimizer=optimizers.RMSprop(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    directory='/content/drive/MyDrive/FARIL-SORG/cartilaginous-tumors-dataset/tuner',
    project_name='multiview_classification')

tuner.search(
    train_generator,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=validation_steps)

best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()

# %% [markdown]
# To create a web browser API for your trained model, you will need to use a web framework such as Flask or Django to create the API endpoint that will handle the incoming requests from the web browser. You will also need to use a web server such as Apache or Nginx to host the API.
#
# ##**Here is an example of how you might use Flask to create a web browser API for your model:**
#
# First, install Flask and other necessary libraries in your colab notebook:
